# %%
import pandas as pd 
df_map = pd.read_csv("data/map_file.csv")
df_map
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         3169   31  Female          Jeans     Clothing
# 1         3728   41  Female          Socks     Clothing
# 2         3362   47  Female          Shoes     Footwear
# 3         1852   28    Male          Skirt     Clothing
# 4         1374   18    Male         Gloves  Accessories
# 5         2631   29    Male          Skirt     Clothing
# 6         1855   25    Male        Sweater     Clothing
# 7         1366   28    Male        Handbag  Accessories
# 8          390   27    Male          Boots     Footwear
# 9         3645   35  Female         Blouse     Clothing
#
#    Purchase Amount (USD)  Location Size      Color  Season  ...  \
# 0                     24   Montana    M     Orange  Spring  ...
# 1                     83     Maine    M       Gold  Summer  ...
# 2                     26   Florida    M     Silver  Spring  ...
# 3                     80  Delaware    S   Lavender    Fall  ...
# ...

# %%
df_map = df_map.drop(['Code'], axis=1)
df_map
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         3169   31  Female          Jeans     Clothing
# 1         3728   41  Female          Socks     Clothing
# 2         3362   47  Female          Shoes     Footwear
# 3         1852   28    Male          Skirt     Clothing
# 4         1374   18    Male         Gloves  Accessories
# 5         2631   29    Male          Skirt     Clothing
# 6         1855   25    Male        Sweater     Clothing
# 7         1366   28    Male        Handbag  Accessories
# 8          390   27    Male          Boots     Footwear
# 9         3645   35  Female         Blouse     Clothing
#
#    Purchase Amount (USD)  Location Size      Color  Season  ...  \
# 0                     24   Montana    M     Orange  Spring  ...
# 1                     83     Maine    M       Gold  Summer  ...
# 2                     26   Florida    M     Silver  Spring  ...
# 3                     80  Delaware    S   Lavender    Fall  ...
# ...

# %%
new_column3 = ['MT', 'ME', 'FL', 'DE', 'VA', 'ME', 'KY', 'IN', 'VA', 'AR']

df_map['Code'] = new_column3
df_map
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         3169   31  Female          Jeans     Clothing
# 1         3728   41  Female          Socks     Clothing
# 2         3362   47  Female          Shoes     Footwear
# 3         1852   28    Male          Skirt     Clothing
# 4         1374   18    Male         Gloves  Accessories
# 5         2631   29    Male          Skirt     Clothing
# 6         1855   25    Male        Sweater     Clothing
# 7         1366   28    Male        Handbag  Accessories
# 8          390   27    Male          Boots     Footwear
# 9         3645   35  Female         Blouse     Clothing
#
#    Purchase Amount (USD)  Location Size      Color  Season  ...  \
# 0                     24   Montana    M     Orange  Spring  ...
# 1                     83     Maine    M       Gold  Summer  ...
# 2                     26   Florida    M     Silver  Spring  ...
# 3                     80  Delaware    S   Lavender    Fall  ...
# ...

# %%
csv_file_path = 'data/map_file.csv'

df_map.to_csv(csv_file_path, index=False)
