# %%
import pandas as pd
import random

customer_ids = range(1, 3901)
customer_segmentation = [random.choice(["New", "Loyal", "VIP"]) for _ in customer_ids]
seasonal_trends = [random.choice(["Christmas present", "Back to school", "Summer preperation", "Pre-fall shopping"]) for _ in customer_ids]
delivery_time = [random.randint(2, 30) for _ in customer_ids]
number_of_items_purchased = [random.randint(1, 9) for _ in customer_ids]

data = {
    'Customer ID': customer_ids,
    'Customer Segmentation': customer_segmentation,
    'Seasonal Trends': seasonal_trends,
    'Delivery Time': delivery_time,
    'Number of Items Purchased': number_of_items_purchased
}

df = pd.DataFrame(data)

df.to_csv('data/customer_data.csv', index=False)

# %%
df_created = pd.read_csv("data/customer_data.csv")
df_created
# Out:
#       Customer ID Customer Segmentation     Seasonal Trends  Delivery Time  \
# 0               1                   New      Back to school             23
# 1               2                 Loyal      Back to school              8
# 2               3                   New  Summer preperation              7
# 3               4                   New   Christmas present             25
# 4               5                   VIP   Pre-fall shopping             26
# ...           ...                   ...                 ...            ...
# 3895         3896                 Loyal   Christmas present             16
# 3896         3897                   New   Christmas present             14
# 3897         3898                   VIP   Christmas present             15
# 3898         3899                 Loyal   Christmas present             27
# 3899         3900                   New  Summer preperation              6
#
#       Number of Items Purchased
# 0                             8
# 1                             8
# 2                             8
# 3                             4
# 4                             6
# ...                         ...
# 3895                          7
# 3896                          2
# 3897                          6
# 3898                          2
# 3899                          1
#
# [3900 rows x 5 columns]

# %%
df = pd.read_csv('data/shopping_trends.csv')
df.head(10)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
# 5        Wyoming    M      White  Summer            2.9                 Yes
# 6        Montana    M       Gray    Fall            3.2                 Yes
# 7      Louisiana    L   Charcoal  Winter            3.2                 Yes
# 8  West Virginia    L     Silver  Summer            2.6                 Yes
# 9       Missouri    M       Pink  Spring            4.8                 Yes
#
#   Payment Method   Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card         Express              Yes             Yes
# 1  Bank Transfer         Express              Yes             Yes
# 2           Cash   Free Shipping              Yes             Yes
# 3         PayPal    Next Day Air              Yes             Yes
# 4           Cash   Free Shipping              Yes             Yes
# 5          Venmo        Standard              Yes             Yes
# 6     Debit Card   Free Shipping              Yes             Yes
# 7     Debit Card   Free Shipping              Yes             Yes
# 8          Venmo         Express              Yes             Yes
# 9         PayPal  2-Day Shipping              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# 0                  14                    Venmo            Fortnightly
# 1                   2                     Cash            Fortnightly
# 2                  23              Credit Card                 Weekly
# 3                  49                   PayPal                 Weekly
# 4                  31                   PayPal               Annually
# 5                  14                    Venmo                 Weekly
# 6                  49                     Cash              Quarterly
# 7                  19              Credit Card                 Weekly
# 8                   8                    Venmo               Annually
# 9                   4                     Cash              Quarterly

# %%
df = df.drop(['Subscription Status'], axis=1)
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# 2                        73  Massachusetts    S     Maroon  Spring
# 3                        90   Rhode Island    M     Maroon  Spring
# 4                        49         Oregon    M  Turquoise  Spring
# ...                     ...            ...  ...        ...     ...
# 3895                     28       Virginia    L  Turquoise  Summer
# 3896                     49           Iowa    L      White  Spring
# 3897                     33     New Jersey    L      Green  Spring
# 3898                     77      Minnesota    S      Brown  Summer
# 3899                     81     California    M      Beige  Spring
#
#       Review Rating Payment Method   Shipping Type Discount Applied  \
# 0               3.1    Credit Card         Express              Yes
# 1               3.1  Bank Transfer         Express              Yes
# 2               3.1           Cash   Free Shipping              Yes
# 3               3.5         PayPal    Next Day Air              Yes
# 4               2.7           Cash   Free Shipping              Yes
# ...             ...            ...             ...              ...
# 3895            4.2           Cash  2-Day Shipping               No
# 3896            4.5         PayPal    Store Pickup               No
# 3897            2.9    Credit Card        Standard               No
# 3898            3.8         PayPal         Express               No
# 3899            3.1  Bank Transfer    Store Pickup               No
#
#      Promo Code Used  Previous Purchases Preferred Payment Method  \
# 0                Yes                  14                    Venmo
# 1                Yes                   2                     Cash
# 2                Yes                  23              Credit Card
# 3                Yes                  49                   PayPal
# 4                Yes                  31                   PayPal
# ...              ...                 ...                      ...
# 3895              No                  32                    Venmo
# 3896              No                  41            Bank Transfer
# 3897              No                  24                    Venmo
# 3898              No                  24                    Venmo
# 3899              No                  33                    Venmo
#
#      Frequency of Purchases
# 0               Fortnightly
# 1               Fortnightly
# 2                    Weekly
# 3                    Weekly
# 4                  Annually
# ...                     ...
# 3895                 Weekly
# 3896              Bi-Weekly
# 3897              Quarterly
# 3898                 Weekly
# 3899              Quarterly
#
# [3900 rows x 18 columns]

# %%
df = pd.merge(df, df_created, how='inner', on='Customer ID')
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                        53       Kentucky    L       Gray  Winter  ...
# 1                        64          Maine    L     Maroon  Winter  ...
# 2                        73  Massachusetts    S     Maroon  Spring  ...
# 3                        90   Rhode Island    M     Maroon  Spring  ...
# 4                        49         Oregon    M  Turquoise  Spring  ...
# ...                     ...            ...  ...        ...     ...  ...
# 3895                     28       Virginia    L  Turquoise  Summer  ...
# 3896                     49           Iowa    L      White  Spring  ...
# 3897                     33     New Jersey    L      Green  Spring  ...
# 3898                     77      Minnesota    S      Brown  Summer  ...
# 3899                     81     California    M      Beige  Spring  ...
#
#        Shipping Type Discount Applied Promo Code Used Previous Purchases  \
# 0            Express              Yes             Yes                 14
# 1            Express              Yes             Yes                  2
# 2      Free Shipping              Yes             Yes                 23
# 3       Next Day Air              Yes             Yes                 49
# 4      Free Shipping              Yes             Yes                 31
# ...              ...              ...             ...                ...
# 3895  2-Day Shipping               No              No                 32
# 3896    Store Pickup               No              No                 41
# 3897        Standard               No              No                 24
# 3898         Express               No              No                 24
# 3899    Store Pickup               No              No                 33
#
#      Preferred Payment Method  Frequency of Purchases Customer Segmentation  \
# 0                       Venmo             Fortnightly                   New
# 1                        Cash             Fortnightly                 Loyal
# 2                 Credit Card                  Weekly                   New
# 3                      PayPal                  Weekly                   New
# 4                      PayPal                Annually                   VIP
# ...                       ...                     ...                   ...
# 3895                    Venmo                  Weekly                 Loyal
# 3896            Bank Transfer               Bi-Weekly                   New
# 3897                    Venmo               Quarterly                   VIP
# 3898                    Venmo                  Weekly                 Loyal
# 3899                    Venmo               Quarterly                   New
#
#          Seasonal Trends Delivery Time Number of Items Purchased
# 0         Back to school            23                         8
# 1         Back to school             8                         8
# 2     Summer preperation             7                         8
# 3      Christmas present            25                         4
# 4      Pre-fall shopping            26                         6
# ...                  ...           ...                       ...
# 3895   Christmas present            16                         7
# 3896   Christmas present            14                         2
# 3897   Christmas present            15                         6
# 3898   Christmas present            27                         2
# 3899  Summer preperation             6                         1
#
# [3900 rows x 22 columns]

# %%
df = df.drop(['Discount Applied', 'Promo Code Used'], axis=1)
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# 2                        73  Massachusetts    S     Maroon  Spring
# 3                        90   Rhode Island    M     Maroon  Spring
# 4                        49         Oregon    M  Turquoise  Spring
# ...                     ...            ...  ...        ...     ...
# 3895                     28       Virginia    L  Turquoise  Summer
# 3896                     49           Iowa    L      White  Spring
# 3897                     33     New Jersey    L      Green  Spring
# 3898                     77      Minnesota    S      Brown  Summer
# 3899                     81     California    M      Beige  Spring
#
#       Review Rating Payment Method   Shipping Type  Previous Purchases  \
# 0               3.1    Credit Card         Express                  14
# 1               3.1  Bank Transfer         Express                   2
# 2               3.1           Cash   Free Shipping                  23
# 3               3.5         PayPal    Next Day Air                  49
# 4               2.7           Cash   Free Shipping                  31
# ...             ...            ...             ...                 ...
# 3895            4.2           Cash  2-Day Shipping                  32
# 3896            4.5         PayPal    Store Pickup                  41
# 3897            2.9    Credit Card        Standard                  24
# 3898            3.8         PayPal         Express                  24
# 3899            3.1  Bank Transfer    Store Pickup                  33
#
#      Preferred Payment Method Frequency of Purchases Customer Segmentation  \
# 0                       Venmo            Fortnightly                   New
# 1                        Cash            Fortnightly                 Loyal
# 2                 Credit Card                 Weekly                   New
# 3                      PayPal                 Weekly                   New
# 4                      PayPal               Annually                   VIP
# ...                       ...                    ...                   ...
# 3895                    Venmo                 Weekly                 Loyal
# 3896            Bank Transfer              Bi-Weekly                   New
# 3897                    Venmo              Quarterly                   VIP
# 3898                    Venmo                 Weekly                 Loyal
# 3899                    Venmo              Quarterly                   New
#
#          Seasonal Trends  Delivery Time  Number of Items Purchased
# 0         Back to school             23                          8
# 1         Back to school              8                          8
# 2     Summer preperation              7                          8
# 3      Christmas present             25                          4
# 4      Pre-fall shopping             26                          6
# ...                  ...            ...                        ...
# 3895   Christmas present             16                          7
# 3896   Christmas present             14                          2
# 3897   Christmas present             15                          6
# 3898   Christmas present             27                          2
# 3899  Summer preperation              6                          1
#
# [3900 rows x 20 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (20, 6))

counts = df["Gender"].value_counts()
explode = (0, 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = ['indigo', 'yellow'], explode = explode, autopct = '%1.1f%%')
plt.xlabel('Gender', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.axis('equal')
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
df_by_gender = df.groupby('Gender')['Purchase Amount (USD)'].sum()

df_by_gender.plot(kind='bar', color=['yellow', 'indigo'])
plt.xlabel('Gender')
plt.ylabel('Purchase Amount (USD)')
plt.show()

# %%
category = df.groupby('Category')['Purchase Amount (USD)'].sum().reset_index()

# %%
category.set_index('Category').plot(kind='barh', color='indigo')
plt.xlabel('Categories')
plt.title('Purchase Amount for each category (USD)')
# Out:
# Text(0.5, 1.0, 'Purchase Amount for each category (USD)')

# %%
items = pd.DataFrame(df['Item Purchased'].unique(), columns=['Clothes'])
items = items.sort_values(by='Clothes')
items.index = range(0, len(items)) 
items
# Out:
#        Clothes
# 0     Backpack
# 1         Belt
# 2       Blouse
# 3        Boots
# 4         Coat
# 5        Dress
# 6       Gloves
# 7      Handbag
# 8          Hat
# 9       Hoodie
# 10      Jacket
# 11       Jeans
# 12     Jewelry
# 13       Pants
# 14     Sandals
# 15       Scarf
# 16       Shirt
# 17       Shoes
# 18      Shorts
# 19       Skirt
# 20    Sneakers
# 21       Socks
# 22  Sunglasses
# 23     Sweater
# 24     T-shirt

# %%
items = df.groupby('Item Purchased')['Purchase Amount (USD)'].sum().reset_index()
items.set_index('Item Purchased').plot(kind='bar', color='yellow')
plt.xlabel('Item Purchased')
plt.title('Purchase Amount for each item (USD)')
# Out:
# Text(0.5, 1.0, 'Purchase Amount for each item (USD)')

# %%
import seaborn as sns
plt.figure(figsize = (16, 6))
df["Location"].value_counts()[:10].sort_values(ascending = False).plot(kind = 'bar', color = sns.color_palette('inferno'), edgecolor = 'black')
plt.xlabel('Location', weight = "bold", color = "black", fontsize = 14, labelpad = 20)
plt.ylabel('\nNumber of Occurrences', weight = "bold", color = 'black', fontsize = 14, labelpad = 20);
plt.xticks(rotation = 0, ha = 'center', fontsize = 16)
plt.tight_layout()
plt.show()

# %%
df["Size"].value_counts()
# Out:
# Size
# M     1755
# L     1053
# S      663
# XL     429
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20, 6))
ax = df["Size"].value_counts().plot(kind = 'bar', color = ['indigo', 'rebeccapurple', 'gold', 'yellow'], rot = 0)
ax.set_xticklabels(('Medium', 'Large', 'Small', 'Extra Large'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)
plt.xlabel('Size', weight = "bold", color = "black", fontsize = 14, labelpad = 20)
plt.ylabel('Number of Occurrences', weight = "bold", color = "black", fontsize = 14, labelpad = 20);

# %%
import numpy as np

grouped_df = df.groupby(['Category', 'Gender']).sum().reset_index()

male_data = grouped_df[grouped_df['Gender'] == 'Male']['Purchase Amount (USD)']
female_data = grouped_df[grouped_df['Gender'] == 'Female']['Purchase Amount (USD)']

width = 0.35

x = np.arange(len(grouped_df['Category'].unique()))

fig, ax = plt.subplots(layout='constrained')
bar1 = ax.bar(x, female_data, width, label='Female', color='yellow')
bar2 = ax.bar(x + width, male_data, width, label='Male', color='indigo')

font2 = {'family':'serif','color':'black','size':15}

ax.set_xlabel('Category')
ax.set_ylabel('Purchase Amount (USD)')
ax.set_title('Purchase Amount by Clothes Category and Gender', fontdict = font2)
ax.set_xticks(x + width / 2)
ax.set_xticklabels(grouped_df['Category'].unique())
ax.legend(loc='upper right', ncols=3)


def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 2),  
                    textcoords="offset points",
                    ha='center', va='bottom')
        
add_labels(bar1)
add_labels(bar2)

plt.show()

# %%
df.head(100)
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 0             1   55   Male         Blouse     Clothing
# 1             2   19   Male        Sweater     Clothing
# 2             3   50   Male          Jeans     Clothing
# 3             4   21   Male        Sandals     Footwear
# 4             5   45   Male         Blouse     Clothing
# ..          ...  ...    ...            ...          ...
# 95           96   37   Male       Sneakers     Footwear
# 96           97   32   Male         Gloves  Accessories
# 97           98   21   Male          Shoes     Footwear
# 98           99   20   Male          Jeans     Clothing
# 99          100   26   Male         Hoodie     Clothing
#
#     Purchase Amount (USD)       Location Size      Color  Season  \
# 0                      53       Kentucky    L       Gray  Winter
# 1                      64          Maine    L     Maroon  Winter
# 2                      73  Massachusetts    S     Maroon  Spring
# 3                      90   Rhode Island    M     Maroon  Spring
# 4                      49         Oregon    M  Turquoise  Spring
# ..                    ...            ...  ...        ...     ...
# 95                    100       Missouri    L       Pink    Fall
# 96                     73       Delaware    S       Gold  Spring
# 97                     92       Virginia    M       Teal  Winter
# 98                     67       New York   XL       Teal  Spring
# 99                     40       Missouri   XL     Indigo  Summer
#
#     Review Rating Payment Method  Shipping Type  Previous Purchases  \
# 0             3.1    Credit Card        Express                  14
# 1             3.1  Bank Transfer        Express                   2
# 2             3.1           Cash  Free Shipping                  23
# 3             3.5         PayPal   Next Day Air                  49
# 4             2.7           Cash  Free Shipping                  31
# ..            ...            ...            ...                 ...
# 95            3.8         PayPal  Free Shipping                  48
# 96            3.6          Venmo        Express                  43
# 97            4.8         PayPal   Store Pickup                  37
# 98            2.6           Cash   Next Day Air                  20
# 99            3.7           Cash        Express                  33
#
#    Preferred Payment Method Frequency of Purchases Customer Segmentation  \
# 0                     Venmo            Fortnightly                   New
# 1                      Cash            Fortnightly                 Loyal
# 2               Credit Card                 Weekly                   New
# 3                    PayPal                 Weekly                   New
# 4                    PayPal               Annually                   VIP
# ..                      ...                    ...                   ...
# 95                   PayPal                Monthly                 Loyal
# 96                    Venmo         Every 3 Months                   VIP
# 97                     Cash               Annually                   VIP
# 98            Bank Transfer               Annually                   New
# 99               Debit Card              Quarterly                 Loyal
#
#        Seasonal Trends  Delivery Time  Number of Items Purchased
# 0       Back to school             23                          8
# 1       Back to school              8                          8
# 2   Summer preperation              7                          8
# 3    Christmas present             25                          4
# 4    Pre-fall shopping             26                          6
# ..                 ...            ...                        ...
# 95  Summer preperation             19                          1
# 96   Pre-fall shopping              9                          6
# 97   Pre-fall shopping             17                          6
# 98      Back to school             16                          8
# 99      Back to school              6                          2
#
# [100 rows x 20 columns]

# %%
plt.scatter(df['Number of Items Purchased'] + np.random.normal(0, 5, size=len(df)),
            df['Review Rating'] + np.random.normal(0, 0.5, size=len(df)),
            c=df['Review Rating'], cmap='gnuplot', alpha=0.7)

plt.colorbar(label='Review Rating')

plt.xlabel('Number of Items Purchased')
plt.ylabel('Review Rating')
plt.title('Review Rating vs Number of Items Purchased')

plt.show()

# %%
frequency_counts = df['Frequency of Purchases'].value_counts()
frequency = pd.DataFrame({'Frequency of Purchases': frequency_counts.index, 'Count': frequency_counts.values})
frequency = frequency.sort_values(by='Frequency of Purchases')
frequency.index = range(len(frequency))

frequency
# Out:
#   Frequency of Purchases  Count
# 0               Annually    572
# 1              Bi-Weekly    547
# 2         Every 3 Months    584
# 3            Fortnightly    542
# 4                Monthly    553
# 5              Quarterly    563
# 6                 Weekly    539

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(frequency['Frequency of Purchases'], frequency['Count'], marker='o', linestyle='-', color = 'indigo')

ax.set_xlabel('Frequency of Purchases')
ax.set_ylabel('Count')
ax.set_title('Frequency of Purchases')

plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.barplot(x='Season', y='Purchase Amount (USD)', hue='Payment Method', data=df)
plt.title('Purchase Amount by Season and Payment Method')
plt.xlabel('Season')
plt.ylabel('Purchase Amount (USD)')
plt.xticks(rotation = 0)
plt.show()

# %%
df_sorted = df.sort_values(by='Number of Items Purchased', ascending=False)
df_top = df_sorted.head(10)
df_top
# Out:
#       Customer ID  Age  Gender Item Purchased   Category  \
# 3894         3895   66  Female          Skirt   Clothing
# 13             14   65    Male          Dress   Clothing
# 3847         3848   60  Female        Sweater   Clothing
# 1743         1744   23    Male          Skirt   Clothing
# 1729         1730   47    Male         Shorts   Clothing
# 3834         3835   43  Female         Hoodie   Clothing
# 1775         1776   18    Male         Jacket  Outerwear
# 1764         1765   61    Male          Dress   Clothing
# 1765         1766   68    Male         Hoodie   Clothing
# 1719         1720   45    Male        Sweater   Clothing
#
#       Purchase Amount (USD)       Location Size     Color  Season  \
# 3894                     78    Connecticut    L     White  Spring
# 13                       51  New Hampshire    M    Violet  Spring
# 3847                     34       Delaware    S      Blue    Fall
# 1743                     72       Missouri   XL     Brown  Winter
# 1729                     21       Illinois    M     Brown  Winter
# 3834                     59      Tennessee    M   Magenta  Winter
# 1775                     47           Iowa    M    Violet  Spring
# 1764                     56       Delaware    M  Charcoal  Summer
# 1765                     88     New Mexico    M    Orange  Spring
# 1719                     39       Maryland    M     White  Winter
#
#       Review Rating Payment Method   Shipping Type  Previous Purchases  \
# 3894            3.9           Cash  2-Day Shipping                  44
# 13              4.7     Debit Card         Express                  31
# 3847            3.2    Credit Card  2-Day Shipping                  31
# 1743            3.3     Debit Card        Standard                   3
# 1729            3.8          Venmo    Store Pickup                  12
# 3834            4.1     Debit Card  2-Day Shipping                  17
# 1775            3.3  Bank Transfer  2-Day Shipping                  12
# 1764            3.0         PayPal    Store Pickup                  34
# 1765            4.1  Bank Transfer  2-Day Shipping                  41
# 1719            3.2          Venmo   Free Shipping                   8
#
#      Preferred Payment Method Frequency of Purchases Customer Segmentation  \
# 3894              Credit Card         Every 3 Months                   New
# 13                     PayPal                 Weekly                 Loyal
# 3847                   PayPal            Fortnightly                   New
# 1743            Bank Transfer                 Weekly                   VIP
# 1729                    Venmo            Fortnightly                 Loyal
# 3834                     Cash              Quarterly                   VIP
# 1775                     Cash              Bi-Weekly                 Loyal
# 1764                    Venmo              Quarterly                   New
# 1765                    Venmo              Quarterly                   New
# 1719                    Venmo              Quarterly                 Loyal
#
#          Seasonal Trends  Delivery Time  Number of Items Purchased
# 3894      Back to school             19                          9
# 13        Back to school             14                          9
# 3847   Pre-fall shopping             27                          9
# 1743      Back to school             29                          9
# 1729  Summer preperation             25                          9
# 3834      Back to school             14                          9
# 1775  Summer preperation             15                          9
# 1764  Summer preperation             26                          9
# 1765  Summer preperation             13                          9
# 1719   Christmas present             15                          9

# %%
new_column1 = [37.8393, 42.4072, 43.8041, 35.0078, 40.4173, 41.4925, 43.1939, 40.6331, 63.5888, 31.9686]
new_column2 = [-84.2700, -71.3824, -120.5542, -97.0929, -82.9071, -99.9018, -71.5724, -89.3985, -154.4931, -99.9018]
new_column3 = ['ID', 'CO', 'MN', 'HI', 'NH', 'MN', 'RI', 'TN', 'VA', 'WA']

df_top.loc[:, 'X'] = new_column1
df_top.loc[:, 'Y'] = new_column2
df_top.loc[:, 'Code'] = new_column3
df_top
# Out:
# /var/folders/jj/py4v5jf97ll0gsvytld5hmx80000gn/T/ipykernel_16028/2891086427.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top.loc[:, 'X'] = new_column1
# /var/folders/jj/py4v5jf97ll0gsvytld5hmx80000gn/T/ipykernel_16028/2891086427.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top.loc[:, 'Y'] = new_column2
# /var/folders/jj/py4v5jf97ll0gsvytld5hmx80000gn/T/ipykernel_16028/2891086427.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top.loc[:, 'Code'] = new_column3
#       Customer ID  Age  Gender Item Purchased   Category  \
# 3894         3895   66  Female          Skirt   Clothing
# 13             14   65    Male          Dress   Clothing
# 3847         3848   60  Female        Sweater   Clothing
# 1743         1744   23    Male          Skirt   Clothing
# 1729         1730   47    Male         Shorts   Clothing
# 3834         3835   43  Female         Hoodie   Clothing
# 1775         1776   18    Male         Jacket  Outerwear
# 1764         1765   61    Male          Dress   Clothing
# 1765         1766   68    Male         Hoodie   Clothing
# 1719         1720   45    Male        Sweater   Clothing
#
#       Purchase Amount (USD)       Location Size     Color  Season  ...  \
# 3894                     78    Connecticut    L     White  Spring  ...
# 13                       51  New Hampshire    M    Violet  Spring  ...
# 3847                     34       Delaware    S      Blue    Fall  ...
# 1743                     72       Missouri   XL     Brown  Winter  ...
# 1729                     21       Illinois    M     Brown  Winter  ...
# 3834                     59      Tennessee    M   Magenta  Winter  ...
# 1775                     47           Iowa    M    Violet  Spring  ...
# 1764                     56       Delaware    M  Charcoal  Summer  ...
# 1765                     88     New Mexico    M    Orange  Spring  ...
# 1719                     39       Maryland    M     White  Winter  ...
#
#       Previous Purchases Preferred Payment Method Frequency of Purchases  \
# 3894                  44              Credit Card         Every 3 Months
# 13                    31                   PayPal                 Weekly
# 3847                  31                   PayPal            Fortnightly
# 1743                   3            Bank Transfer                 Weekly
# 1729                  12                    Venmo            Fortnightly
# 3834                  17                     Cash              Quarterly
# 1775                  12                     Cash              Bi-Weekly
# 1764                  34                    Venmo              Quarterly
# 1765                  41                    Venmo              Quarterly
# 1719                   8                    Venmo              Quarterly
#
#       Customer Segmentation     Seasonal Trends Delivery Time  \
# 3894                    New      Back to school            19
# 13                    Loyal      Back to school            14
# 3847                    New   Pre-fall shopping            27
# 1743                    VIP      Back to school            29
# 1729                  Loyal  Summer preperation            25
# 3834                    VIP      Back to school            14
# 1775                  Loyal  Summer preperation            15
# 1764                    New  Summer preperation            26
# 1765                    New  Summer preperation            13
# 1719                  Loyal   Christmas present            15
#
#      Number of Items Purchased        X         Y  Code
# 3894                         9  37.8393  -84.2700    ID
# 13                           9  42.4072  -71.3824    CO
# 3847                         9  43.8041 -120.5542    MN
# 1743                         9  35.0078  -97.0929    HI
# 1729                         9  40.4173  -82.9071    NH
# 3834                         9  41.4925  -99.9018    MN
# 1775                         9  43.1939  -71.5724    RI
# 1764                         9  40.6331  -89.3985    TN
# 1765                         9  63.5888 -154.4931    VA
# 1719                         9  31.9686  -99.9018    WA
#
# [10 rows x 23 columns]

# %%
csv_file_path = 'data/map_file.csv'

df_top.to_csv(csv_file_path, index=False)

# %%
import folium
m = folium.Map([37.0902, -95.7129], zoom_start=5)
items = folium.map.FeatureGroup()

for lat, lng, in zip(df_top.X, df_top.Y):
    items.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius = 5,
            color = 'yellow', 
            fill_color = 'indigo',
            fill_opacity = 0.9
        )
    )
m.add_child(items)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed0cdb7a2212dcc3289c64d6a67c9306 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed0cdb7a2212dcc3289c64d6a67c9306&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed0cdb7a2212dcc3289c64d6a67c9306 = L.map(
#                 &quot;map_ed0cdb7a2212dcc3289c64d6a67c9306&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b198ab951dc532d3e7c0a7e48e4ce37a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b198ab951dc532d3e7c0a7e48e4ce37a.addTo(map_ed0cdb7a2212dcc3289c64d6a67c9306);
#
#
#             var feature_group_df00881b0f28a4b38c031d9b68326e92 = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_e13652740e705f445b0e266b9270257c = L.circleMarker(
#                 [37.8393, -84.27],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;indigo&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_df00881b0f28a4b38c031d9b68326e92);
#
#
#             var circle_marker_9cb04612956f2b469535bca567346888 = L.circleMarker(
#                 [42.4072, -71.3824],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;indigo&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_df00881b0f28a4b38c031d9b68326e92);
#
#
#             var circle_marker_63915a14929b32db13b3b5590be2cc30 = L.circleMarker(
#                 [43.8041, -120.5542],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;indigo&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_df00881b0f28a4b38c031d9b68326e92);
#
#
#             var circle_marker_c624209ee9b471bfeb599f987e3fcf92 = L.circleMarker(
#                 [35.0078, -97.0929],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;indigo&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_df00881b0f28a4b38c031d9b68326e92);
#
#
#             var circle_marker_d97c00f997d08d8f30b608da452ba809 = L.circleMarker(
#                 [40.4173, -82.9071],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;indigo&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_df00881b0f28a4b38c031d9b68326e92);
#
#
#             var circle_marker_1f344dfe604588df47a203ea4737f001 = L.circleMarker(
#                 [41.4925, -99.9018],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;indigo&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_df00881b0f28a4b38c031d9b68326e92)

# %%
from wordcloud import WordCloud

text = ' '.join(df['Item Purchased'])

wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='gnuplot', max_words=None).generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off') 
plt.title('Items')
plt.show()

# %%
import numpy as np
from PIL import Image

cloud_mask = np.array(Image.open('images/cloud.png'))
    
print('Image downloaded and saved!')
# Out:
# Image downloaded and saved!

# %%
fig = plt.figure()
fig.set_figwidth(14) 
fig.set_figheight(18) 

plt.imshow(cloud_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white', 
                      colormap='gnuplot', max_words=None, mask=cloud_mask,
                      contour_width=3, contour_color='indigo').generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
